# %% [markdown]
# ### Development Notebook

# %%
# Import libraries
from bs4 import BeautifulSoup as bs
import requests

# %%
url = 'https://www.dotabuff.com/players/76482434/matches'
header= {'User-Agent':
         'Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/537.36 (KHTML like Gecko) Chrome/44.0.2403.155 Safari/537.36',
         'Accept': '*/*'}
request = requests.get(url,headers=header)
soup = bs(request.content, 'html.parser')

# %%
type(request)
# Out:
# requests.models.Response

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    Alliance.AdmiralBulldog - Matches - DOTABUFF - Dota 2 Stats
#   </title>
#   <link href="/assets/application-bed34d1d35a7adda77da3090e623533e62d15e2cafa43817aec2b66e151604e3.css" media="all" rel="stylesheet"/>
#   <link href="https://www.dotabuff.com/blog.rss" rel="alternate" title="RSS" type="application/rss+xml"/>
#   <script src="/assets/application-1101a895b15863c0d846939c638981db3aef22b34f0ea966e9aaea95b5acc313.js">
#   </script>
#   <script async="async" src="https://k9v7.dotabuff.com/a.js" type="text/javascript">
#   </script>
#   <meta content="authenticity_token" name="csrf-param"/>
#   <meta content="6q+b++jWBMhGHJoW8mXoAOC94HLSWPiiPaOowCRbG5a9Eu/pIQvhv0LKlNG6V9+t4K1RfsBWzK4hBkPgthEX0w==" name="csrf-token"/>
#   <meta content="dota 2 statistics, dota 2 stats, dota 2, statistics, dota, hero builds, guides" name="keywords"/>
#   <meta content="en" name="locale"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <meta content="#242F39" name="theme-color"/>
#   <meta content="Alliance.AdmiralBulldog - Matches" property="og:title"/>
#   <meta content="View the complete Dota 2 profile for Alliance.AdmiralBulldog on Dotabuff" property="og:description"/>
#   <meta content="https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/4c/4c419a1c02ce7e67cf193359f3be254c35095344_full.jpg" property="og:image"/>
#   <meta content="https://www.dotabuff.com/players/76482434/matches" property="og:url"/>
#   <meta content="profile" property="og:type"/>
#   <meta content="View the complete Dota 2 profile for Alliance.AdmiralBulldog on Dotabuff" name="description"/>
#   <link href="/assets/favicon-a6c9d750400872d536f8d3376a67851d3d5ee5a9b3d1beda17c66ab92ad62cdb.png" rel="icon" type="image/png"/>
#   <link href="/assets/favicon-retina-d5a61fdd725d0d4a1469b880ebd0e36d782c47f27b395bea2551c8b7b0dea51a.png" rel="apple-touch-icon-precomposed" sizes="114x114"/>
#   <link href="/assets/favicon-ipad-993f82f47b26a766bfa652bfde6420c91ddd746c774c10bb90337b05b9823340.png" rel="apple-touch-icon-precomposed" sizes="72x72"/>
#   <link href="/assets/favicon-iphone-1e6ec36d4dec75ef88d10038359d8c4998f9fdfe1e867877754d23ac7db18629.png" rel="apple-touch-icon-precomposed"/>
#   <link href="//bg.dotabuff.com/players/76482434/matches" hreflang="bg" rel="alternate"/>
#   <link href="//cs.dotabuff.com/players/76482434/matches" hreflang="cs" rel="alternate"/>
#   <link href="//de.dotabuff.com/players/76482434/matches" hreflang="de" rel="alternate"/>
#   <link href="//www.dotabuff.com/players/76482434/matches" hreflang="en" rel="alternate"/>
#   <link href="//es.dotabuff.com/players/76482434/matches" hreflang="es" rel="alternate"/>
#   <link href="//fr.dotabuff.com/players/76482434/matches" hreflang="fr" rel="alternate"/>
#   <link href="//it.dotabuff.com/players/76482434/matches" hreflang="it" rel="alternate"/>
#   <link href="//ka.dotabuff.com/players/76482434/matches" hreflang="ka" rel="alternate"/>
#   <link href="//ko.dotabuff.com/players/76482434/matches" hreflang="ko" rel="alternate"/>
#   <link href="//pl.dotabuff.com/players/76482434/matches" hreflang="pl" rel="alternate"/>
#   <link href="//pt.dotabuff.com/players/76482434/matches" hreflang="pt" rel="alternate"/>
#   <link href="//ru.dotabuff.com/players/76482434/matches" hreflang="ru" rel="alternate"/>
#   <link href="//sr.dotabuff.com/players/76482434/matches" hreflang="sr" rel="alternate"/>
#   <link href="//tr.dotabuff.com/players/76482434/matches" hreflang="tr" rel="alternate"/>
#   <link href="//uk.dotabuff.com/players/76482434/matches" hreflang="uk" rel="alternate"/>
#   <link href="//zh.dotabuff.com/players/76482434/matches" hreflang="zh" rel="alternate"/>
#   <link crossorigin="" href="https://steamcdn-a.akamaihd.net" rel="preconnect"/>
#   <link crossorigin="" href="https://www.google-analytics.com" rel="preconnect"/>
#   <link crossorigin="" href="https://riki.dotabuff.com" rel="preconnect"/>
#   <script>
#    var analytics_src = "https://www.google-analytics.com/analytics.js"; (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function() { (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o), m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m) })(window,document,'script',analytics_src,'ga'); ga("create", "UA-34232227-1", "auto"); ga("set", "forceSSL", true); ga("require", "ec"); ga("set", "page", "/players/matches"); ga("set", "dimension2", "false"); ga("send", "pageview");
#   </script>
#  </head>
#  <body>
#   <div class="container-outer seemsgood">
#    <div class="header-nav-primary">
#     <div class="container-inner">
#      <a class="header-menu-toggle" href="#">
#       <i class="fa fa-bars">
#       </i>
#       <span>
#        DOTABUFF
#       </span>
#       <a class="header-nav-logo" href="/">
#        Dotabuff
#       </a>
#      </a>
#      <nav class="header-nav-links">
#       <ul>
#        <li class="">
#         <a class="r-only-tablet" href="/">
#          Home
#         </a>
#        </li>
#        <li class="">
#         <a class="color-pro-circuit js-has-children" data-target="#header-nav-secondary-collection-procircuit" href="/procircuit">
#          Pro Circuit
#         </a>
#        </li>
#        <li class="">
#         <a class="color-esports js-has-children" data-target="#header-nav-secondary-collection-esports" href="/esports">
#          Esports
#         </a>
#        </li>
#        <li class="">
#         <a class="js-has-children" data-target="#header-nav-secondary-collection-heroes" href="/heroes">
#          Heroes
#         </a>
#        </li>
#        <li class="">
#         <a class="js-has-children" data-target="#header-nav-secondary-collection-items" href="/items">
#          Items
#         </a>
#        </li>
#        <li class="active">
#         <a class="js-has-children" data-target="#header-nav-secondary-collection-players" href="/players">
#          Players
#         </a>
#        </li>
#        <li class="">
#         <a class="js-has-children" data-target="#header-nav-secondary-collection-matches" href="/matches">
#          Matches
#         </a>
#        </li>
#        <li class="">
#         <a href="/blog">
#          Blog
#         </a>
#        </li>
#        <li class="">
#         <a href="/forums/general">
#          Forums
#         </a>
#        </li>
#        <li class="">
#         <a class="color-premium" href="/plus">
#          Plus
#         </a>
#        </li>
#       </ul>
#      </nav>
#      <div class="header-nav-right">
#       <div class="header-nav-search-input">
#        <form accept-charset="UTF-8" action="/search" method="get">
#         <input name="utf8" type="hidden" value="✓"/>
#         <input autocomplete="off" id="q" name="q" placeholder="Search for heroes, items, players, leagues, teams..." size="48" spellcheck="false" type="text" value=""/>
#         <input name="commit" type="submit" value="Search"/>
#         <p>
#          You can
#          <a href="/signin">
#           Sign in with Steam
#          </a>
#          to see your Dota 2 profile.
#         </p>
#        </form>
#       </div>
#       <a class="header-nav-search-toggle" href="#">
#        <i class="fa fa-search">
#        </i>
#       </a>
#       <nav class="header-nav-session">
#        <ul>
#         <li class="">
#          <a href="/signin">
#           <i class="fa fa-steam">
#           </i>
#           Sign In
#          </a>
#         </li>
#        </ul>
#       </nav>
#      </div>
#     </div>
#    </div>
#    <div class="header-nav-secondary-collection" id="header-nav-secondary-collection-procircuit">
#     <div class="container-inner">
#      <nav class="header-nav-links">
#       <ul>
#        <li class="">
#         <a href="/procircuit">
#          Pro Circuit
#         </a>
#        </li>
#        <li class="">
#         <a href="/procircuit/team-standings">
#          Team Standings
#         </a>
#        </li>
#        <li class="">
#         <a href="/procircuit/schedule">
#          Schedule
#         </a>
#        </li>
#        <li class="">
#         <a href="/procircuit/events">
#          Events
#         </a>
#        </li>
#        <li class="">
#         <a href="/procircuit/results">
#          Results
#         </a>
#        </li>
#        <li class="">
#         <a href="/procircuit/2017-2018">
#          2017 - 2018 Season
#         </a>
#        </li>
#       </ul>
#      </nav>
#     </div>
#    </div>
#    <div class="header-nav-secondary-collection" id="header-nav-secondary-collection-esports">
#     <div class="container-inner">
#      <nav class="header-nav-links">
#       <ul>
#        <li class="">
#         <a href="/esports">
#          Esports
#         </a>
#        </li>
#        <li class="">
#         <a href="/clips">
#          Clips
#          <span class="designation-new r-none-mobile">
#           NEW!
#          </span>
#         </a>
#        </li>
#        <li class="">
#         <a href="/esports/series">
#          Series
#         </a>
#        </li>
#        <li class="">
#         <a href="/esports/scores">
#          Scores
#         </a>
#        </li>
#        <li class="">
#         <a href="/esports/leagues">
#          Leagues
#         </a>
#        </li>
#        <li class="">
#         <a href="/esports/players">
#          Players
#         </a>
#        </li>
#        <li class="">
#         <a href="/esports/teams">
#          Teams
#         </a>
#        </li>
#        <li class="">
#         <a href="/esports/matches">
#          Matches
#         </a>
#        </li>
#       </ul>
#      </nav>
#     </div>
#    </div>
#    <div class="header-nav-secondary-collection" id="header-nav-secondary-collection-heroes">
#     <div class="container-inner">
#      <nav class="header-nav-links">
#       <ul>
#        <li class="">
#         <a href="/heroes">
#          All Heroes
#         </a>
#        </li>
#        <li class="">
#         <a href="/heroes/meta">
#          Meta
#         </a>
#        </li>
#        <li class="">
#         <a href="/heroes/trends">
#          Trends
#         </a>
#        </li>
#        <li class="">
#         <a href="/heroes/lanes">
#          Lanes
#         </a>
#        </li>
#        <li class="">
#         <a href="/heroes/played">
#          Most Played
#         </a>
#        </li>
#        <li class="">
#         <a href="/heroes/winning">
#          Win Rate
#         </a>
#        </li>
#        <li class="">
#         <a href="/heroes/impact">
#          Game Impact
#         </a>
#        </li>
#        <li class="">
#         <a href="/heroes/economy">
#          Economy
#         </a>
#        </li>
#        <li class="">
#         <a href="/heroes/farm">
#          Farm
#         </a>
#        </li>
#        <li class="">
#         <a href="/heroes/damage">
#          Damage and Healing
#         </a>
#        </li>
#       </ul>
#      </nav>
#     </div>
#    </div>
#    <div class="header-nav-secondary-collection" id="header-nav-secondary-collection-items">
#     <div class="container-inner">
#      <nav class="header-nav-links">
#       <ul>
#        <li class="">
#         <a href="/items">
#          Most Used
#         </a>
#        </li>
#        <li class="">
#         <a href="/items/winning">
#          Win Rate
#         </a>
#        </li>
#        <li class="">
#         <a href="/items/impact">
#          Game Impact
#         </a>
#        </li>
#        <li class="">
#         <a href="/items/economy">
#          Economy
#         </a>
#        </li>
#        <li class="">
#         <a href="/cosmetics">
#          Cosmetics
#         </a>
#        </li>
#       </ul>
#      </nav>
#     </div>
#    </div>
#    <div class="header-nav-secondary-collection active" id="header-nav-secondary-collection-players">
#     <div class="container-inner">
#      <nav class="header-nav-links">
#       <ul>
#        <li class="">
#         <a href="/players">
#          Verified
#         </a>
#        </li>
#        <li class="">
#         <a href="/players/leaderboard">
#          Ranked Leaderboard
#          <span class="designation-new r-none-mobile">
#           NEW!
#          </span>
#         </a>
#        </li>
#        <li class="">
#         <a href="/achievements">
#          Achievements
#         </a>
#        </li>
#        <li class="">
#         <a href="/players/winning">
#          Highest Win Rate
#         </a>
#        </li>
#        <li class="">
#         <a href="/players/played">
#          Most Matches Played
#         </a>
#        </li>
#        <li class="">
#         <a href="/players/duration">
#          Time Spent Playing
#         </a>
#        </li>
#       </ul>
#      </nav>
#     </div>
#    </div>
#    <div class="header-nav-secondary-collection" id="header-nav-secondary-collection-matches">
#     <div class="container-inner">
#      <nav class="header-nav-links">
#       <ul>
#        <li class="">
#         <a class="color-esports" href="/esports">
#          Live Matches
#         </a>
#        </li>
#        <li class="">
#         <a class="color-esports" href="/esports/matches">
#          Recent Esports Matches
#         </a>
#        </li>
#        <li class="">
#         <a href="/matches">
#          Recent Matches
#         </a>
#        </li>
#        <li class="">
#         <a href="/siltbreaker">
#          Siltbreaker
#         </a>
#        </li>
#        <li class="">
#         <a href="/darkmoon">
#          Dark Moon
#         </a>
#        </li>
#       </ul>
#      </nav>
#     </div>
#    </div>
#    <div class="container-inner container-inner-content">
#     <div class="elo-placement leaderboard_a" data-area="player" data-site="dotabuff" data-space="leaderboard_a" data-type="elo-placement">
#     </div>
#     <div class="header-content-container">
#      <div class="header-content">
#       <div class="header-content-primary">
#        <div class="header-content-avatar">
#         <div class="image-container image-container-player image-container-bigavatar">
#          <a href="/players/76482434">
#           <img alt="Alliance.AdmiralBulldog" class="image-player image-bigavatar" data-tooltip-url="/players/76482434/tooltip" rel="tooltip-remote" src="https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/4c/4c419a1c02ce7e67cf193359f3be254c35095344_full.jpg" title="Alliance.AdmiralBulldog"/>
#          </a>
#         </div>
#        </div>
#        <div class="header-content-title">
#         <h1>
#          Alliance.AdmiralBulldog
#          <small>
#           Matches
#          </small>
#          <span class="header-content-title-flair">
#           <a href="/players">
#            <i class="fa fa-check color-verified fa-space-right" rel="tooltip" title="This player is verified as Alliance.AdmiralBulldog">
#            </i>
#           </a>
#           <a href="/plus">
#            <i class="fa fa-plus color-premium fa-space-right" rel="tooltip" title="Alliance.AdmiralBulldog has Dotabuff Plus!">
#            </i>
#           </a>
#           <a data-track-outgoing="true" href="https://twitter.com/AdmiralBulldog">
#            <i class="fa fa-twitter color-brand-twitter fa fa-space-right" rel="tooltip" title="@AdmiralBulldog on twitter">
#            </i>
#           </a>
#           <a data-track-outgoing="true" href="https://twitch.tv/AdmiralBulldog">
#            <i class="fa fa-twitch color-brand-twitch fa fa-space-right fa-twitch" rel="tooltip" title="AdmiralBulldog on twitch.tv">
#            </i>
#           </a>
#           <a data-track-outgoing="true" href="https://www.facebook.com/AdmiralBulldog">
#            <i class="fa fa-facebook-square color-brand-facebook fa fa-space-right" rel="tooltip" title="AdmiralBulldog on facebook.com">
#            </i>
#           </a>
#           <a data-track-outgoing="true" href="https://www.youtube.com/channel/UCk8ZIMJxSO9-pUg7xyrnaFQ">
#            <i class="fa fa-youtube-play color-brand-youtube fa fa-space-right" rel="tooltip" title="AdmiralBulldog on youtube.com">
#            </i>
#           </a>
#           <i class="fa fa-phone qualifies-for-phone" rel="tooltip" title="This player has a verified phone number and has played a ranked match within the last month.">
#           </i>
#          </span>
#         </h1>
#        </div>
#       </div>
#       <div class="header-content-secondary">
#        <dl>
#         <dd>
#          <time data-time-ago="2019-09-30T12:50:04+00:00" datetime="2019-09-30T12:50:04+00:00" title="Mon, 30 Sep 2019 12:50:04 +0000">
#           2019-09-30
#          </time>
#         </dd>
#         <dt>
#          Last Match
#         </dt>
#        </dl>
#        <dl>
#         <dd class="rating-expired">
#          6435
#          <i class="fa fa-exclamation-triangle" rel="neighbour-tooltip">
#          </i>
#          <div style="display: none">
#           Last Updated
#           <time datetime="2017-11-27T18:53:08+00:00" title="Mon, 27 Nov 2017 18:53:08 +0000">
#            2017-11-27
#           </time>
#          </div>
#         </dd>
#         <dt>
#          Solo MMR
#         </dt>
#        </dl>
#        <dl>
#         <dd class="rating-expired">
#          6454
#          <i class="fa fa-exclamation-triangle" rel="neighbour-tooltip">
#          </i>
#          <div style="display: none">
#           Last Updated
#           <time datetime="2017-07-27T12:28:23+00:00" title="Thu, 27 Jul 2017 12:28:23 +0000">
#            2017-07-27
#           </time>
#          </div>
#         </dd>
#         <dt>
#          Party MMR
#         </dt>
#        </dl>
#        <dl>
#         <dd>
#          <span class="game-record">
#           <span class="wins">
#            2,658
#           </span>
#           <span class="sep">
#            -
#           </span>
#           <span class="losses">
#            1,635
#           </span>
#           <span class="sep">
#            -
#           </span>
#           <span class="abandons">
#            66
#           </span>
#          </span>
#         </dd>
#         <dt>
#          Record
#         </dt>
#        </dl>
#        <dl>
#         <dd>
#          60.98%
#         </dd>
#         <dt>
#          Win Rate
#         </dt>
#        </dl>
#        <div class="rank-tier-wrapper" rel="tooltip" title="Rank: #520 - Immortal">
#         <div class="rank-tier-images">
#          <img alt=" " class="rank-tier-base" src="https://riki.dotabuff.com/c/914a49d64c118ee0c1ee9b82757b9604c9f300cb/68747470733a2f2f7261772e67697468756275736572636f6e74656e742e636f6d2f646f7461627566662f70616e6f72616d612f6d61737465722f70616e6f72616d612f696d616765732f72616e6b5f746965725f69636f6e732f72616e6b385f7073642e706e67"/>
#          <div alt=" " class="leaderboard-rank-value">
#           520
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="header-content-interactive">
#        <div class="player-header-interactive hide-if-empty">
#         <a class="button-esports button-small button" href="/esports/players/76482434">
#          <i class="fa fa-trophy fa-space-right">
#          </i>
#          Esports profile
#         </a>
#        </div>
#       </div>
#      </div>
#      <div class="header-content-nav-container">
#       <div class="header-content-nav">
#        <nav class="header-nav-links header-nav-links-condensed">
#         <ul>
#          <li class="">
#           <a href="/players/76482434">
#            Overview
#           </a>
#          </li>
#          <li class="active">
#           <a href="/players/76482434/matches">
#            Matches
#           </a>
#          </li>
#          <li class="">
#           <a href="/players/76482434/heroes">
#            Heroes
#           </a>
#          </li>
#          <li class="">
#           <a href="/players/76482434/items">
#            Items
#           </a>
#          </li>
#          <li class="dropdown">
#           <a class="dropdown-trigger" href="#">
#            More
#           </a>
#           <ul class="dropdown-menu">
#            <li class="">
#             <a href="/players/76482434/records">
#              Records
#             </a>
#            </li>
#            <li class="">
#             <a href="/players/76482434/scenarios">
#              Scenarios
#             </a>
#            </li>
#            <li class="">
#             <a href="/players/76482434/activity">
#              Activity
#             </a>
#            </li>
#            <li class="">
#             <a href="/players/76482434/trends">
#              Trends
#             </a>
#            </li>
#            <li class="">
#             <a href="/players/76482434/achievements">
#              Achievements
#             </a>
#            </li>
#            <li class="">
#             <a class="color-premium" data-toggle="modal" href="#plus-feature">
#              Matchups
#             </a>
#            </li>
#           </ul>
#          </li>
#         </ul>
#        </nav>
#       </div>
#      </div>
#     </div>
#     <div class="content-inner">
#      <section>
#       <div class="filter inline-filter" data-filter-remote="yes">
#        <form action="" method="get">
#         <article>
#          <div class="settings">
#           <div class="description">
#            Filter:
#           </div>
#           <dl class="setting">
#            <dd>
#             <div class="select">
#              <select class="" id="date" name="date" options="{}">
#               <option disabled="disabled" selected="selected" value="">
#                Time
#               </option>
#               <option value="all">
#                All Time
#               </option>
#               <option disabled="disabled" value="separator">
#                ────────
#               </option>
#               <option value="week">
#                This Week
#               </option>
#               <option value="month">
#                This Month
#               </option>
#               <option value="3month">
#                Last 3 Months
#               </option>
#               <option value="6month">
#                Last 6 Months
#               </option>
#               <option value="year">
#                Last 12 Months
#               </option>
#               <option disabled="disabled" value="separator_season">
#                ────────
#               </option>
#               <option value="season_4">
#                Ranked Season 4
#               </option>
#               <option value="season_3">
#                Ranked Season 3
#               </option>
#               <option value="season_2">
#                Ranked Season 2
#               </option>
#               <option value="season_1">
#                Ranked Season 1
#               </option>
#               <option disabled="disabled" value="separator_patch">
#                ────────
#               </option>
#               <option value="patch_7.22">
#                Patch 7.22
#               </option>
#               <option value="patch_7.21">
#                Patch 7.21
#               </option>
#               <option value="patch_7.20">
#                Patch 7.20
#               </option>
#               <option value="patch_7.19">
#                Patch 7.19
#               </option>
#               <option value="patch_7.18">
#                Patch 7.18
#               </option>
#               <option value="patch_7.17">
#                Patch 7.17
#               </option>
#              </select>
#             </div>
#            </dd>
#           </dl>
#           <dl class="setting">
#            <dd>
#             <div class="select">
#              <select class="" id="skill_bracket" name="skill_bracket" options="{}">
#               <option disabled="disabled" selected="selected" value="">
#                Skill
#               </option>
#               <option value="">
#                Any Skill
#               </option>
#               <option disabled="disabled" value="separator1">
#                ────────
#               </option>
#               <option value="normal_skill">
#                Normal Skill
#               </option>
#               <option value="high_skill">
#                High Skill
#               </option>
#               <option value="very_high_skill">
#                Very High Skill
#               </option>
#              </select>
#             </div>
#            </dd>
#           </dl>
#           <dl class="setting">
#            <dd>
#             <div class="select">
#              <select class="" id="lobby_type" name="lobby_type" options="{}">
#               <option disabled="disabled" selected="selected" value="">
#                Lobby
#               </option>
#               <option value="">
#                Any Lobby
#               </option>
#               <option disabled="disabled" value="separator1">
#                ────────
#               </option>
#               <option value="normal_matchmaking">
#                Normal Matchmaking
#               </option>
#               <option value="ranked_matchmaking">
#                Ranked Matchmaking
#               </option>
#               <option value="battle_cup">
#                Battle Cup
#               </option>
#               <option disabled="disabled" value="separator2">
#                ──── Not Used: ────
#               </option>
#               <option value="team_matchmaking">
#                Team Matchmaking
#               </option>
#               <option value="solo_matchmaking">
#                Solo Matchmaking
#               </option>
#               <option value="custom">
#                Custom
#               </option>
#              </select>
#             </div>
#            </dd>
#           </dl>
#           <dl class="setting">
#            <dd>
#             <div class="select">
#              <select class="" id="game_mode" name="game_mode" options="{}">
#               <option disabled="disabled" selected="selected" value="">
#                Game Mode
#               </option>
#               <option value="">
#                Any Mode
#               </option>
#               <option disabled="disabled" value="separator1">
#                ────────
#               </option>
#               <option value="all_pick">
#                All Pick
#               </option>
#               <option value="turbo">
#                Turbo
#               </option>
#               <option value="mutation">
#                Mutation
#               </option>
#               <option value="captains_mode">
#                Captains Mode
#               </option>
#               <option value="random_draft">
#                Random Draft
#               </option>
#               <option value="single_draft">
#                Single Draft
#               </option>
#               <option value="captains_draft">
#                Captains Draft
#               </option>
#               <option disabled="disabled" value="separator2">
#                ────────
#               </option>
#               <option value="1v1_solo_mid">
#                1v1 Solo Mid
#               </option>
#               <option value="ability_draft">
#                Ability Draft
#               </option>
#               <option value="all_random">
#                All Random
#               </option>
#               <option value="all_random_deathmatch">
#                All Random Deathmatch
#               </option>
#               <option value="least_played">
#                Least Played
#               </option>
#               <option value="pool1">
#                Limited Hero Pool
#               </option>
#              </select>
#             </div>
#            </dd>
#           </dl>
#           <dl class="setting">
#            <dd>
#             <div class="select">
#              <select class="" id="region" name="region" options="{}">
#               <option disabled="disabled" selected="selected" value="">
#                Region
#               </option>
#               <option value="">
#                Any Region
#               </option>
#               <option disabled="disabled" value="separator">
#                ────────
#               </option>
#               <option value="us_west">
#                US West
#               </option>
#               <option value="us_east">
#                US East
#               </option>
#               <option value="europe_west">
#                Europe West
#               </option>
#               <option value="south_korea">
#                South Korea
#               </option>
#               <option value="se_asia">
#                SE Asia
#               </option>
#               <option value="chile">
#                Chile
#               </option>
#               <option value="australia">
#                Australia
#               </option>
#               <option value="russia">
#                Russia
#               </option>
#               <option value="europe_east">
#                Europe East
#               </option>
#               <option value="south_america">
#                South America
#               </option>
#               <option value="south_africa">
#                South Africa
#               </option>
#               <option value="china">
#                China
#               </option>
#               <option value="dubai">
#                Dubai
#               </option>
#               <option value="peru">
#                Peru
#               </option>
#               <option value="india">
#                India
#               </option>
#              </select>
#             </div>
#            </dd>
#           </dl>
#           <dl class="setting">
#            <dd>
#             <div class="select">
#              <select class="" id="faction" name="faction" options="{}">
#               <option disabled="disabled" selected="selected" value="">
#                Faction
#               </option>
#               <option value="">
#                Any Faction
#               </option>
#               <option disabled="disabled" value="separator">
#                ────────
#               </option>
#               <option value="radiant">
#                Radiant
#               </option>
#               <option value="dire">
#                Dire
#               </option>
#              </select>
#             </div>
#            </dd>
#           </dl>
#           <dl class="setting">
#            <dd>
#             <div class="select">
#              <select class="" id="duration" name="duration" options="{}">
#               <option disabled="disabled" selected="selected" value="">
#                Duration
#               </option>
#               <option value="">
#                Any Duration
#               </option>
#               <option disabled="disabled" value="separator1">
#                ────────
#               </option>
#               <option value="12-">
#                &gt; 12 Min
#               </option>
#               <option value="20-">
#                &gt; 20 Min
#               </option>
#               <option value="30-">
#                &gt; 30 Min
#               </option>
#               <option value="40-">
#                &gt; 40 Min
#               </option>
#               <option value="50-">
#                &gt; 50 Min
#               </option>
#               <option value="60-">
#                &gt; 60 Min
#               </option>
#               <option disabled="disabled" value="separator2">
#                ────────
#               </option>
#               <option value="0-20">
#                &lt; 20 Min
#               </option>
#               <option value="20-30">
#                20 - 30 Min
#               </option>
#               <option value="30-40">
#                30 - 40 Min
#               </option>
#               <option value="40-50">
#                40 - 50 Min
#               </option>
#               <option value="50-60">
#                50 - 60 Min
#               </option>
#              </select>
#             </div>
#            </dd>
#           </dl>
#           <dl class="setting">
#            <dd>
#             <div class="select">
#              <select class="" id="party_size" name="party_size" options="{}">
#               <option disabled="disabled" selected="selected" value="">
#                Solo/Party
#               </option>
#               <option value="">
#                Any Party Size
#               </option>
#               <option disabled="disabled" value="separator1">
#                ────────
#               </option>
#               <option value="solo">
#                Solo Queue
#               </option>
#               <option value="dual_plus">
#                Party Queue (2+)
#               </option>
#               <option disabled="disabled" value="separator2">
#                ────────
#               </option>
#               <option value="dual">
#                2-Stack
#               </option>
#               <option value="tri">
#                3-Stack
#               </option>
#               <option value="quad">
#                4-Stack
#               </option>
#               <option value="pent">
#                5-Stack
#               </option>
#               <option disabled="disabled" value="separator3">
#                ────────
#               </option>
#               <option value="tri_plus">
#                3 or more
#               </option>
#               <option value="quad_plus">
#                4 or more
#               </option>
#              </select>
#             </div>
#            </dd>
#           </dl>
#           <dl class="setting">
#            <dd>
#             <div class="select">
#              <select class="truesight" id="parse_status" name="parse_status" options="{}">
#               <option disabled="disabled" selected="selected" value="">
#                TrueSight
#               </option>
#               <option value="">
#                Any Status
#               </option>
#               <option disabled="disabled" value="separator">
#                ────────
#               </option>
#               <option value="parsed">
#                Only Analyzed Matches
#               </option>
#               <option value="not_parsed">
#                Exclude Analyzed Matches
#               </option>
#              </select>
#             </div>
#            </dd>
#           </dl>
#           <dl class="setting">
#            <dd>
#             <div class="select">
#              <select class="truesight" id="captain_status" name="captain_status" options="{}">
#               <option disabled="disabled" selected="selected" value="">
#                Captain
#               </option>
#               <option value="">
#                Any Status
#               </option>
#               <option disabled="disabled" value="separator">
#                ────────
#               </option>
#               <option value="captained">
#                Only Captained Matches
#               </option>
#               <option value="not_captain">
#                Exclude Captained Matches
#               </option>
#              </select>
#             </div>
#            </dd>
#           </dl>
#           <dl class="setting">
#            <dd>
#             <div class="select">
#              <select class="truesight" id="random_status" name="random_status" options="{}">
#               <option disabled="disabled" selected="selected" value="">
#                Random
#               </option>
#               <option value="">
#                Any Status
#               </option>
#               <option disabled="disabled" value="separator">
#                ────────
#               </option>
#               <option value="randomed">
#                Only Randomed Matches
#               </option>
#               <option value="not_random">
#                Exclude Randomed Matches
#               </option>
#              </select>
#             </div>
#            </dd>
#           </dl>
#           <dl class="setting">
#            <dd>
#             <div class="select">
#              <select class="" id="significance" name="significance" options="{}">
#               <option disabled="disabled" selected="selected" value="">
#                Significance
#               </option>
#               <option value="">
#                Any Signifiance
#               </option>
#               <option disabled="disabled" value="separator">
#                ────────
#               </option>
#               <option value="significant">
#                Significant Matches Only
#               </option>
#               <option value="not_significant">
#                Insignificant Matches Only
#               </option>
#              </select>
#             </div>
#            </dd>
#           </dl>
#           <i class="fa fa-question-circle" rel="tooltip" title='Only matches with human players on both teams are "significant". A normal match can also be marked as insignificant if there is an early abandon or if the game ended prematurely due to bad network conditions.'>
#           </i>
#          </div>
#         </article>
#         <div class="row-12">
#          <div class="col-8">
#           <article>
#            <div class="role-filters">
#             <div class="filter-group">
#              <div class="filter-status">
#               <div class="description full">
#                <span>
#                 Filter by Heroes, Roles, Lanes
#                </span>
#               </div>
#              </div>
#              <div class="filter-role">
#               <div class="description full">
#                Player:
#                <i class="fa fa-question-circle" rel="tooltip" title="This player's laning strategy. Choose as many options as you need.">
#                </i>
#               </div>
#               <div class="settings">
#                <dl class="setting">
#                 <dd>
#                  <div class="select">
#                   <select class="" id="hero" name="hero" options="{}">
#                    <option disabled="disabled" selected="selected" value="">
#                     Hero
#                    </option>
#                    <option value="">
#                     All Heroes
#                    </option>
#                    <option disabled="disabled" value="separator">
#                     ────────
#                    </option>
#                    <option value="abaddon">
#                     Abaddon
#                    </option>
#                    <option value="alchemist">
#                     Alchemist
#                    </option>
#                    <option value="ancient-apparition">
#                     Ancient Apparition
#                    </option>
#                    <option value="anti-mage">
#                     Anti-Mage
#                    </option>
#                    <option value="arc-warden">
#                     Arc Warden
#                    </option>
#                    <option value="axe">
#                     Axe
#                    </option>
#                    <option value="bane">
#                     Bane
#                    </option>
#                    <option value="batrider">
#                     Batrider
#                    </option>
#                    <option value="beastmaster">
#                     Beastmaster
#                    </option>
#                    <option value="bloodseeker">
#                     Bloodseeker
#                    </option>
#                    <option value="bounty-hunter">
#                     Bounty Hunter
#                    </option>
#                    <option value="brewmaster">
#                     Brewmaster
#                    </option>
#                    <option value="bristleback">
#                     Bristleback
#                    </option>
#                    <option value="broodmother">
#                     Broodmother
#                    </option>
#                    <option value="centaur-warrunner">
#                     Centaur Warrunner
#                    </option>
#                    <option value="chaos-knight">
#                     Chaos Knight
#                    </option>
#                    <option value="chen">
#                     Chen
#                    </option>
#                    <option value="clinkz">
#                     Clinkz
#                    </option>
#                    <option value="clockwerk">
#                     Clockwerk
#                    </option>
#                    <option value="crystal-maiden">
#                     Crystal Maiden
#                    </option>
#                    <option value="dark-seer">
#                     Dark Seer
#                    </option>
#                    <option value="dark-willow">
#                     Dark Willow
#                    </option>
#                    <option value="dazzle">
#                     Dazzle
#                    </option>
#                    <option value="death-prophet">
#                     Death Prophet
#                    </option>
#                    <option value="disruptor">
#                     Disruptor
#                    </option>
#                    <option value="doom">
#                     Doom
#                    </option>
#                    <option value="dragon-knight">
#                     Dragon Knight
#                    </option>
#                    <option value="drow-ranger">
#                     Drow Ranger
#                    </option>
#                    <option value="earth-spirit">
#                     Earth Spirit
#                    </option>
#                    <option value="earthshaker">
#                     Earthshaker
#                    </option>
#                    <option value="elder-titan">
#                     Elder Titan
#                    </option>
#                    <option value="ember-spirit">
#                     Ember Spirit
#                    </option>
#                    <option value="enchantress">
#                     Enchantress
#                    </option>
#                    <option value="enigma">
#                     Enigma
#                    </option>
#                    <option value="faceless-void">
#                     Faceless Void
#                    </option>
#                    <option value="grimstroke">
#                     Grimstroke
#                    </option>
#                    <option value="gyrocopter">
#                     Gyrocopter
#                    </option>
#                    <option value="huskar">
#                     Huskar
#                    </option>
#                    <option value="invoker">
#                     Invoker
#                    </option>
#                    <option value="io">
#                     Io
#                    </option>
#                    <option value="jakiro">
#                     Jakiro
#                    </option>
#                    <option value="juggernaut">
#                     Juggernaut
#                    </option>
#                    <option value="keeper-of-the-light">
#                     Keeper of the Light
#                    </option>
#                    <option value="kunkka">
#                     Kunkka
#                    </option>
#                    <option value="legion-commander">
#                     Legion Commander
#                    </option>
#                    <option value="leshrac">
#                     Leshrac
#                    </option>
#                    <option value="lich">
#                     Lich
#                    </option>
#                    <option value="lifestealer">
#                     Lifestealer
#                    </option>
#                    <option value="lina">
#                     Lina
#                    </option>
#                    <option value="lion">
#                     Lion
#                    </option>
#                    <option value="lone-druid">
#                     Lone Druid
#                    </option>
#                    <option value="luna">
#                     Luna
#                    </option>
#                    <option value="lycan">
#                     Lycan
#                    </option>
#                    <option value="magnus">
#                     Magnus
#                    </option>
#                    <option value="mars">
#                     Mars
#                    </option>
#                    <option value="medusa">
#                     Medusa
#                    </option>
#                    <option value="meepo">
#                     Meepo
#                    </option>
#                    <option value="mirana">
#                     Mirana
#                    </option>
#                    <option value="monkey-king">
#                     Monkey King
#                    </option>
#                    <option value="morphling">
#                     Morphling
#                    </option>
#                    <option value="naga-siren">
#                     Naga Siren
#                    </option>
#                    <option value="natures-prophet">
#                     Nature's Prophet
#                    </option>
#                    <option value="necrophos">
#                     Necrophos
#                    </option>
#                    <option value="night-stalker">
#                     Night Stalker
#                    </option>
#                    <option value="nyx-assassin">
#                     Nyx Assassin
#                    </option>
#                    <option value="ogre-magi">
#                     Ogre Magi
#                    </option>
#                    <option value="omniknight">
#                     Omniknight
#                    </option>
#                    <option value="oracle">
#                     Oracle
#                    </option>
#                    <option value="outworld-devourer">
#                     Outworld Devourer
#                    </option>
#                    <option value="pangolier">
#                     Pangolier
#                    </option>
#                    <option value="phantom-assassin">
#                     Phantom Assassin
#                    </option>
#                    <option value="phantom-lancer">
#                     Phantom Lancer
#                    </option>
#                    <option value="phoenix">
#                     Phoenix
#                    </option>
#                    <option value="puck">
#                     Puck
#                    </option>
#                    <option value="pudge">
#                     Pudge
#                    </option>
#                    <option value="pugna">
#                     Pugna
#                    </option>
#                    <option value="queen-of-pain">
#                     Queen of Pain
#                    </option>
#                    <option value="razor">
#                     Razor
#                    </option>
#                    <option value="riki">
#                     Riki
#                    </option>
#                    <option value="rubick">
#                     Rubick
#                    </option>
#                    <option value="sand-king">
#                     Sand King
#                    </option>
#                    <option value="shadow-demon">
#                     Shadow Demon
#                    </option>
#                    <option value="shadow-fiend">
#                     Shadow Fiend
#                    </option>
#                    <option value="shadow-shaman">
#                     Shadow Shaman
#                    </option>
#                    <option value="silencer">
#                     Silencer
#                    </option>
#                    <option value="skywrath-mage">
#                     Skywrath Mage
#                    </option>
#                    <option value="slardar">
#                     Slardar
#                    </option>
#                    <option value="slark">
#                     Slark
#                    </option>
#                    <option value="sniper">
#                     Sniper
#                    </option>
#                    <option value="spectre">
#                     Spectre
#                    </option>
#                    <option value="spirit-breaker">
#                     Spirit Breaker
#                    </option>
#                    <option value="storm-spirit">
#                     Storm Spirit
#                    </option>
#                    <option value="sven">
#                     Sven
#                    </option>
#                    <option value="techies">
#                     Techies
#                    </option>
#                    <option value="templar-assassin">
#                     Templar Assassin
#                    </option>
#                    <option value="terrorblade">
#                     Terrorblade
#                    </option>
#                    <option value="tidehunter">
#                     Tidehunter
#                    </option>
#                    <option value="timbersaw">
#                     Timbersaw
#                    </option>
#                    <option value="tinker">
#                     Tinker
#                    </option>
#                    <option value="tiny">
#                     Tiny
#                    </option>
#                    <option value="treant-protector">
#                     Treant Protector
#                    </option>
#                    <option value="troll-warlord">
#                     Troll Warlord
#                    </option>
#                    <option value="tusk">
#                     Tusk
#                    </option>
#                    <option value="underlord">
#                     Underlord
#                    </option>
#                    <option value="undying">
#                     Undying
#                    </option>
#                    <option value="ursa">
#                     Ursa
#                    </option>
#                    <option value="vengeful-spirit">
#                     Vengeful Spirit
#                    </option>
#                    <option value="venomancer">
# ...
#             </span>
#             <div class="subtext">
#              Very High Skill
#              <div class="grouped-icons r-only-mobile">
#               <i class="fa fa-role-core fa-fw role-icon core-icon" rel="tooltip" title="Core Role">
#               </i>
#               <i class="fa fa-lane-safelane fa-fw lane-icon safelane-icon" rel="tooltip" title="Safe Lane">
#               </i>
#              </div>
#             </div>
#            </td>
#            <td class="cell-centered r-none-mobile">
#             <i class="fa fa-role-core fa-fw role-icon core-icon" rel="tooltip" title="Core Role">
#             </i>
#             <i class="fa fa-lane-safelane fa-fw lane-icon safelane-icon" rel="tooltip" title="Safe Lane">
#             </i>
#            </td>
#            <td>
#             <a class="lost" href="/matches/5030025626">
#              Lost Match
#             </a>
#             <div class="subtext">
#              <time data-time-ago="2019-09-19T12:15:10+00:00" datetime="2019-09-19T12:15:10+00:00" title="Thu, 19 Sep 2019 12:15:10 +0000">
#               2019-09-19
#              </time>
#             </div>
#            </td>
#            <td class="r-none-mobile">
#             Ranked
#             <span rel="tooltip" title="Party Queue (2-stack)">
#              <i class="fa fa-users fa-space">
#              </i>
#              <small class="subtitle">
#               x2
#              </small>
#             </span>
#             <div class="subtext">
#              All Pick
#             </div>
#            </td>
#            <td>
#             37:39
#             <div class="bar bar-default">
#              <div class="segment segment-duration" style="width: 71.8740057270124%;">
#              </div>
#             </div>
#            </td>
#            <td>
#             <span class="kda-record">
#              <span class="value">
#               5
#              </span>
#              /
#              <span class="value">
#               8
#              </span>
#              /
#              <span class="value">
#               17
#              </span>
#             </span>
#             <div class="bar bar-default">
#              <div class="segment segment-kill" style="width: 16%;">
#              </div>
#              <div class="segment segment-death" style="width: 26%;">
#              </div>
#              <div class="segment segment-assist" style="width: 56%;">
#              </div>
#             </div>
#            </td>
#            <td class="r-none-tablet cell-xxlarge">
#             <div class="match-item-with-time match-item-with-time-plusicon">
#              <div class="image-container image-container-item image-container-plusicon image-container-overlay">
#               <a href="/items/power-treads">
#                <img class="image-item image-plusicon image-overlay" data-tooltip-url="/items/power-treads/tooltip" rel="tooltip-remote" src="/assets/items/power-treads-ead692931ccfbcbb43f63b29d1282eb21a387e13eea6763a2b4117f8f3efc0cc.jpg" title="Power Treads"/>
#                <span class="overlay-text bottom left">
#                 4m
#                </span>
#               </a>
#              </div>
#             </div>
#             <div class="match-item-with-time match-item-with-time-plusicon">
#              <div class="image-container image-container-item image-container-plusicon image-container-overlay">
#               <a href="/items/magic-wand">
#                <img class="image-item image-plusicon image-overlay" data-tooltip-url="/items/magic-wand/tooltip" rel="tooltip-remote" src="/assets/items/magic-wand-7a4f7e78733470ac31dd40d01c85661493535044e799bc6676971fb90e2ed747.jpg" title="Magic Wand"/>
#                <span class="overlay-text bottom left">
#                 8m
#                </span>
#               </a>
#              </div>
#             </div>
#             <div class="match-item-with-time match-item-with-time-plusicon">
#              <div class="image-container image-container-item image-container-plusicon image-container-overlay">
#               <a href="/items/wraith-band">
#                <img class="image-item image-plusicon image-overlay" data-tooltip-url="/items/wraith-band/tooltip" rel="tooltip-remote" src="/assets/items/wraith-band-18366a5bf1f31f382a101d9f7462c2be86fa7c07c14a14d0dcb2cf5fb5d2a7ec.jpg" title="Wraith Band"/>
#                <span class="overlay-text bottom left">
#                 8m
#                </span>
#               </a>
#              </div>
#             </div>
#             <div class="match-item-with-time match-item-with-time-plusicon">
#              <div class="image-container image-container-item image-container-plusicon image-container-overlay">
#               <a href="/items/aghanims-scepter">
#                <img class="image-item image-plusicon image-overlay" data-tooltip-url="/items/aghanims-scepter/tooltip" rel="tooltip-remote" src="/assets/items/aghanims-scepter-72bdb9aee9187bc224f24985bf92100a34b1ba630991a240d7ccb26ba899079e.jpg" title="Aghanim's Scepter"/>
#                <span class="overlay-text bottom left">
#                 19m
#                </span>
#               </a>
#              </div>
#             </div>
#             <div class="match-item-with-time match-item-with-time-plusicon">
#              <div class="image-container image-container-item image-container-plusicon image-container-overlay">
#               <a href="/items/hurricane-pike">
#                <img class="image-item image-plusicon image-overlay" data-tooltip-url="/items/hurricane-pike/tooltip" rel="tooltip-remote" src="/assets/items/hurricane-pike-3af50aa5181d94db649e65729a3db1e7b43d8db111964a6b7012d91f468fdb28.jpg" title="Hurricane Pike"/>
#                <span class="overlay-text bottom left">
#                 32m
#                </span>
#               </a>
#              </div>
#             </div>
#             <div class="match-item-with-time match-item-with-time-plusicon">
#              <div class="image-container image-container-item image-container-plusicon image-container-overlay">
#               <a href="/items/cheese">
#                <img class="image-item image-plusicon image-overlay" data-tooltip-url="/items/cheese/tooltip" rel="tooltip-remote" src="/assets/items/cheese-0ad4ef80221348dc914649d24d6e1da279a48742ad691f72f589151d8342e096.jpg" title="Cheese"/>
#                <span class="overlay-text bottom left">
#                 35m
#                </span>
#               </a>
#              </div>
#             </div>
#            </td>
#           </tr>
#          </tbody>
#         </table>
#         <div class="viewport">
#          1 - 50 of 6089
#         </div>
#         <nav class="pagination">
#          <span class="page current">
#           1
#          </span>
#          <span class="page">
#           <a href="/players/76482434/matches?enhance=overview&amp;page=2" rel="next">
#            2
#           </a>
#          </span>
#          <span class="page">
#           <a href="/players/76482434/matches?enhance=overview&amp;page=3">
#            3
#           </a>
#          </span>
#          <span class="page">
#           <a href="/players/76482434/matches?enhance=overview&amp;page=4">
#            4
#           </a>
#          </span>
#          <span class="page">
#           <a href="/players/76482434/matches?enhance=overview&amp;page=5">
#            5
#           </a>
#          </span>
#          <span class="page gap">
#           …
#          </span>
#          <span class="next">
#           <a href="/players/76482434/matches?enhance=overview&amp;page=2" rel="next">
#            Next ›
#           </a>
#          </span>
#          <span class="last">
#           <a href="/players/76482434/matches?enhance=overview&amp;page=122">
#            Last »
#           </a>
#          </span>
#         </nav>
#        </article>
#       </section>
#      </section>
#      <div class="elo-placement leaderboard_b" data-area="player" data-site="dotabuff" data-space="leaderboard_b" data-type="elo-placement">
#      </div>
#     </div>
#     <div class="footer-nav-primary">
#      <nav class="footer-nav-primary-locales">
#       <ul class="dropit">
#        <li class="dropit-trigger">
#         <a class="current-locale en" href="#">
#          <div class="flag flag-en">
#          </div>
#          English (English)
#          <span class="arrow-selector">
#           ▴
#          </span>
#         </a>
#         <ul class="dropit-submenu">
#          <li class="bg">
#           <a href="//bg.dotabuff.com/players/76482434/matches">
#            <div class="flag flag-bg">
#            </div>
#            български (Bulgarian)
#           </a>
#          </li>
#          <li class="cs">
#           <a href="//cs.dotabuff.com/players/76482434/matches">
#            <div class="flag flag-cs">
#            </div>
#            Čeština (Czech)
#           </a>
#          </li>
#          <li class="de">
#           <a href="//de.dotabuff.com/players/76482434/matches">
#            <div class="flag flag-de">
#            </div>
#            Deutsch (German)
#           </a>
#          </li>
#          <li class="en active">
#           <a href="//www.dotabuff.com/players/76482434/matches">
#            <div class="flag flag-en">
#            </div>
#            English (English)
#            <i class="fa fa-check">
#            </i>
#           </a>
#          </li>
#          <li class="es">
#           <a href="//es.dotabuff.com/players/76482434/matches">
#            <div class="flag flag-es">
#            </div>
#            Español (Spanish)
#           </a>
#          </li>
#          <li class="fr">
#           <a href="//fr.dotabuff.com/players/76482434/matches">
#            <div class="flag flag-fr">
#            </div>
#            Français (French)
#           </a>
#          </li>
#          <li class="it">
#           <a href="//it.dotabuff.com/players/76482434/matches">
#            <div class="flag flag-it">
#            </div>
#            Italiano (Italian)
#           </a>
#          </li>
#          <li class="ka">
#           <a href="//ka.dotabuff.com/players/76482434/matches">
#            <div class="flag flag-ka">
#            </div>
#            ქართული (Georgian)
#           </a>
#          </li>
#          <li class="ko">
#           <a href="//ko.dotabuff.com/players/76482434/matches">
#            <div class="flag flag-ko">
#            </div>
#            한국어 (Korean)
#           </a>
#          </li>
#          <li class="pl">
#           <a href="//pl.dotabuff.com/players/76482434/matches">
#            <div class="flag flag-pl">
#            </div>
#            polski (Polish)
#           </a>
#          </li>
#          <li class="pt">
#           <a href="//pt.dotabuff.com/players/76482434/matches">
#            <div class="flag flag-pt">
#            </div>
#            Português brasileiro (Portuguese)
#           </a>
#          </li>
#          <li class="ru">
#           <a href="//ru.dotabuff.com/players/76482434/matches">
#            <div class="flag flag-ru">
#            </div>
#            Русский (Russian)
#           </a>
#          </li>
#          <li class="sr">
#           <a href="//sr.dotabuff.com/players/76482434/matches">
#            <div class="flag flag-sr">
#            </div>
#            српски (Serbian)
#           </a>
#          </li>
#          <li class="tr">
#           <a href="//tr.dotabuff.com/players/76482434/matches">
#            <div class="flag flag-tr">
#            </div>
#            Türkçe (Turkish)
#           </a>
#          </li>
#          <li class="uk">
#           <a href="//uk.dotabuff.com/players/76482434/matches">
#            <div class="flag flag-uk">
#            </div>
#            українська (Ukrainian)
#           </a>
#          </li>
#          <li class="zh">
#           <a href="//zh.dotabuff.com/players/76482434/matches">
#            <div class="flag flag-zh">
#            </div>
#            中文 (Chinese)
#           </a>
#          </li>
#         </ul>
#        </li>
#       </ul>
#      </nav>
#      <div class="footer-nav-right">
#       <nav>
#        <ul>
#         <li>
#          <a href="/pages/about">
#           About
#          </a>
#         </li>
#         <li>
#          <a href="/pages/faq">
#           FAQ
#          </a>
#         </li>
#         <li>
#          <a href="/pages/about#support">
#           Support
#          </a>
#         </li>
#         <li>
#          <a href="/pages/privacy">
#           Privacy
#          </a>
#         </li>
#         <li>
#          <a data-track-outgoing="true" href="https://dotabuff.statuspage.io" rel="noopener" target="_blank">
#           Service Status
#          </a>
#         </li>
#         <li>
#          <a href="/pages/translate">
#           Help Translate!
#          </a>
#         </li>
#         <li>
#          <a data-track-outgoing="true" href="https://www.overbuff.com" rel="noopener" target="_blank">
#           Overbuff
#          </a>
#         </li>
#         <li>
#          <a data-track-outgoing="true" href="https://www.fortbuff.com" rel="noopener" target="_blank">
#           Fortbuff
#          </a>
#         </li>
#         <li>
#          <a data-track-outgoing="true" href="http://www.trackdota.com" rel="noopener" target="_blank">
#           TrackDota
#          </a>
#         </li>
#         <li>
#          <a class="color-brand-facebook" data-track-outgoing="true" href="https://www.facebook.com/dotabuff" rel="noopener" target="_blank">
#           <i class="fa fa-facebook">
#           </i>
#          </a>
#         </li>
#         <li>
#          <a class="color-brand-twitter" data-track-outgoing="true" href="https://twitter.com/dotabuff" rel="noopener" target="_blank">
#           <i class="fa fa-twitter">
#           </i>
#          </a>
#         </li>
#         <li>
#          <a class="color-brand-discord" data-track-outgoing="true" href="https://discord.gg/dotabuff" rel="noopener" target="_blank">
#           <i class="fa fa-discord">
#           </i>
#          </a>
#         </li>
#        </ul>
#       </nav>
#      </div>
#     </div>
#     <div class="footer-nav-secondary">
#      Copyright 2019
#      <a data-track-outgoing="true" href="https://elo.io" rel="noopener" target="_blank">
#       Elo Entertainment LLC
#      </a>
#      .
#      <a data-track-outgoing="true" href="https://elo.workable.com" rel="noopener" target="_blank">
#       We're Hiring!
#      </a>
#      Dota 2 is a registered trademark of Valve Corporation.
#      <div class="footer-nav-right">
#       <a class="button button-small toggle-cb-on symbol-button symbol on-button">
#        <i class="fa fa-eye">
#        </i>
#        Turn on colorblind mode
#       </a>
#       <a class="button button-small toggle-cb-off symbol-button symbol off-button">
#        <i class="fa fa-eye-slash">
#        </i>
#        Turn off colorblind mode
#       </a>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="modal seemsgood" id="plus-feature" style="display: none">
#    <section>
#     <header class="premium">
#      Dotabuff Plus
#     </header>
#     <footer style="max-width: 600px">
#      <p>
#       <em>
#        This feature is only available to Dotabuff Plus members.
#       </em>
#      </p>
#      <p style="padding: 8px 0 0 0">
#       Support from Plus members keep Dotabuff running and help enable us to deliver new features for everyone. As a reward, some features that are difficult or expensive to operate are available only to Plus members. Additionally, Plus members never see any advertisements!
#      </p>
#      <p style="padding: 12px 0 0 0">
#       <a class="button button-premium" href="/plus">
#        Tell me more...
#       </a>
#       <a class="button button-muted simplemodal-close" href="/plus">
#        Nevermind
#       </a>
#      </p>
#     </footer>
#    </section>
#   </div>
#   <div class="elo-placement skin" data-area="player" data-site="dotabuff" data-space="skin" data-type="elo-placement">
#   </div>
#   <!-- Quantcast Tag -->
#   <script type="text/javascript">
#    var _qevents = _qevents || [];
#
# (function() {
# var elem = document.createElement('script');
# elem.src = (document.location.protocol == "https:" ? "https://secure" : "http://edge") + ".quantserve.com/quant.js";
# elem.async = true;
# elem.type = "text/javascript";
# var scpt = document.getElementsByTagName('script')[0];
# scpt.parentNode.insertBefore(elem, scpt);
# })();
#
# _qevents.push({
# qacct:"p-kE_YTEQhq5e4s"
# });
#   </script>
#   <noscript>
#    <div style="display:none;">
#     <img alt="Quantcast" border="0" height="1" src="//pixel.quantserve.com/pixel/p-kE_YTEQhq5e4s.gif" width="1"/>
#    </div>
#   </noscript>
#   <!-- End Quantcast tag -->
#  </body>
# </html>

# %%
main_content = soup.find_all('td',{'class':'cell-large'})

# %%
main_content[0]
# Out:
# <td class="cell-large"><a href="/matches/5047913350">Invoker</a><span class="subtext icons"></span><div class="subtext">Very High Skill<div class="grouped-icons r-only-mobile"><i class="fa fa-role-core fa-fw role-icon core-icon" rel="tooltip" title="Core Role"></i><i class="fa fa-lane-midlane fa-fw lane-icon midlane-icon" rel="tooltip" title="Mid Lane"></i></div></div></td>
